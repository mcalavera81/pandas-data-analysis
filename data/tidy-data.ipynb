# %%
import pandas as pd

# %%
pwe = pd.read_csv('../data/pew_raw.csv')

# %%
pwe
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pwe_long = pd.melt(pwe, id_vars='religion')
pwe_long.head()
# Out:
#              religion variable  value
# 0            Agnostic    <$10k     27
# 1             Atheist    <$10k     12
# 2            Buddhist    <$10k     27
# 3            Catholic    <$10k    418
# 4  Don’t know/refused    <$10k     15

# %%
pwe_long = pd.melt(pwe, id_vars='religion',var_name='income', value_name='count')
pwe_long.head(10)
# Out:
#                   religion income  count
# 0                 Agnostic  <$10k     27
# 1                  Atheist  <$10k     12
# 2                 Buddhist  <$10k     27
# 3                 Catholic  <$10k    418
# 4       Don’t know/refused  <$10k     15
# 5         Evangelical Prot  <$10k    575
# 6                    Hindu  <$10k      1
# 7  Historically Black Prot  <$10k    228
# 8        Jehovah's Witness  <$10k     20
# 9                   Jewish  <$10k     19

# %%
billboard = pd.read_csv('../data/billboard-raw.csv')
billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 1  2000         2 Pac           Baby Don't Cry  4:22   2000-02-26   87  82.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...   wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  92.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  72.0  77.0  87.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# ...

# %%
billboard_long = pd.melt(billboard,id_vars=['year','artist','track','time','date.entered'],var_name='week', value_name='rating')
billboard_long
# Out:
#        year                artist                    track  time date.entered  \
# 0      2000               2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 1      2000                 2 Pac           Baby Don't Cry  4:22   2000-02-26
# 2      2000          3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000          3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000              504 Boyz            Wobble Wobble  3:35   2000-04-15
# 5      2000                   98?  Give Me Just One Nig...  3:24   2000-08-19
# 6      2000               Aaliyah            I Don't Wanna  4:15   2000-01-29
# 7      2000               Aaliyah                Try Again  4:03   2000-03-18
# 8      2000        Adams, Yolanda            Open My Heart  5:30   2000-08-26
# 9      2000         Adkins, Trace                     More  3:05   2000-04-29
# 10     2000   Aguilera, Christina        Come On Over Baby  3:38   2000-08-05
# ...

# %%
ebola = pd.read_csv('../data/ebola_country_timeseries.csv')
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %% [markdown]
# ### Melt

# %%
ebola_long = pd.melt(ebola, id_vars=['Date', 'Day'])
ebola_long.head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
variable_split = ebola_long.variable.str.split('_')
variable_split.head()
# Out:
# 0    [Cases, Guinea]
# 1    [Cases, Guinea]
# 2    [Cases, Guinea]
# 3    [Cases, Guinea]
# 4    [Cases, Guinea]
# Name: variable, dtype: object

# %%
status_value,country_value = variable_split.str.get(0), variable_split.str.get(1)
print(status_value.head())
print(country_value.head())
# Out:
# 0    Cases
# 1    Cases
# 2    Cases
# 3    Cases
# 4    Cases
# Name: variable, dtype: object
# 0    Guinea
# 1    Guinea
# 2    Guinea
# 3    Guinea
# 4    Guinea
# Name: variable, dtype: object

# %%
type(variable_split),type(variable_split.str)
# Out:
# (pandas.core.series.Series, pandas.core.strings.StringMethods)

# %%
ebola_long['status'] = status_value
ebola_long['country'] = country_value
ebola_long.head()
# Out:
#          Date  Day      variable   value status country
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea

# %%
var_split= ebola_long.variable.str.split('_', expand=True)
var_split.columns=['status_2','country_2']
var_split[:5]
# Out:
#   status_2 country_2
# 0    Cases    Guinea
# 1    Cases    Guinea
# 2    Cases    Guinea
# 3    Cases    Guinea
# 4    Cases    Guinea

# %%
pd.concat([ebola_long, var_split],axis=1).head()
# Out:
#          Date  Day      variable   value status country status_2 country_2
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea    Cases    Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea    Cases    Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea    Cases    Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea    Cases    Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea    Cases    Guinea

# %%
ebola_long['status_3'], ebola_long['country_3']= zip(*ebola_long.variable.str.split('_'))
ebola_long.head()
# Out:
#          Date  Day      variable   value status country status_3 country_3
# 0    1/5/2015  289  Cases_Guinea  2776.0  Cases  Guinea    Cases    Guinea
# 1    1/4/2015  288  Cases_Guinea  2775.0  Cases  Guinea    Cases    Guinea
# 2    1/3/2015  287  Cases_Guinea  2769.0  Cases  Guinea    Cases    Guinea
# 3    1/2/2015  286  Cases_Guinea     NaN  Cases  Guinea    Cases    Guinea
# 4  12/31/2014  284  Cases_Guinea  2730.0  Cases  Guinea    Cases    Guinea

# %%
a,b = zip(*ebola_long.variable.str.split('_'))

# %%
list(zip(['Cases','Mali'],['Cases','Burkina']))
# Out:
# [('Cases', 'Cases'), ('Mali', 'Burkina')]

# %%
ebola_long.variable.str.split('_')
# Out:
# 0       [Cases, Guinea]
# 1       [Cases, Guinea]
# 2       [Cases, Guinea]
# 3       [Cases, Guinea]
# 4       [Cases, Guinea]
# 5       [Cases, Guinea]
# 6       [Cases, Guinea]
# 7       [Cases, Guinea]
# 8       [Cases, Guinea]
# 9       [Cases, Guinea]
# 10      [Cases, Guinea]
# 11      [Cases, Guinea]
# 12      [Cases, Guinea]
# 13      [Cases, Guinea]
# 14      [Cases, Guinea]
# 15      [Cases, Guinea]
# 16      [Cases, Guinea]
# 17      [Cases, Guinea]
# 18      [Cases, Guinea]
# 19      [Cases, Guinea]
# 20      [Cases, Guinea]
# 21      [Cases, Guinea]
# 22      [Cases, Guinea]
# 23      [Cases, Guinea]
# 24      [Cases, Guinea]
# 25      [Cases, Guinea]
# 26      [Cases, Guinea]
# 27      [Cases, Guinea]
# 28      [Cases, Guinea]
# 29      [Cases, Guinea]
#              ...
# 1922     [Deaths, Mali]
# 1923     [Deaths, Mali]
# 1924     [Deaths, Mali]
# 1925     [Deaths, Mali]
# 1926     [Deaths, Mali]
# 1927     [Deaths, Mali]
# 1928     [Deaths, Mali]
# ...

# %%
weather = pd.read_csv('../data/weather.csv')
weather.tail(20)
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...   \
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 12  MX17004  2010      7    tmax   NaN   NaN  28.6   NaN   NaN   NaN  ...
# 13  MX17004  2010      7    tmin   NaN   NaN  17.5   NaN   NaN   NaN  ...
# ...

# %%
weather_melt =pd.melt(weather, id_vars=['id','year','month','element'],var_name='day', value_name='temp')
weather_melt.head()
# Out:
#         id  year  month element day  temp
# 0  MX17004  2010      1    tmax  d1   NaN
# 1  MX17004  2010      1    tmin  d1   NaN
# 2  MX17004  2010      2    tmax  d1   NaN
# 3  MX17004  2010      2    tmin  d1   NaN
# 4  MX17004  2010      3    tmax  d1   NaN

# %%
weather_tidy = weather_melt.pivot_table(index=['id','year','month','day'], columns='element', values='temp')
weather_tidy.dropna()
# Out:
# element                 tmax  tmin
# id      year month day
# MX17004 2010 1     d30  27.8  14.5
#              2     d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4
#              3     d10  34.5  16.8
#                    d16  31.1  17.6
#                    d5   32.1  14.2
#              4     d27  36.3  16.7
#              5     d27  33.2  18.2
#              6     d17  28.0  17.5
#                    d29  30.1  18.0
#              7     d14  29.9  16.5
#                    d3   28.6  17.5
#              8     d13  29.8  16.5
#                    d23  26.4  15.0
#                    d25  29.7  15.6
#                    d29  28.0  15.3
#                    d31  25.4  15.4
#                    d5   29.6  15.8
#                    d8   29.0  17.3
#              10    d14  29.5  13.0
#                    d15  28.7  10.5
#                    d28  31.2  15.0
#                    d5   27.0  14.0
# ...

# %%
weather_tidy_flat = weather_tidy.reset_index()
weather_tidy_flat.dropna()
# Out:
# element       id  year  month  day  tmax  tmin
# 23       MX17004  2010      1  d30  27.8  14.5
# 33       MX17004  2010      2  d11  29.7  13.4
# 42       MX17004  2010      2   d2  27.3  14.4
# 46       MX17004  2010      2  d23  29.9  10.7
# 53       MX17004  2010      2   d3  24.1  14.4
# 63       MX17004  2010      3  d10  34.5  16.8
# 69       MX17004  2010      3  d16  31.1  17.6
# 88       MX17004  2010      3   d5  32.1  14.2
# 112      MX17004  2010      4  d27  36.3  16.7
# 143      MX17004  2010      5  d27  33.2  18.2
# 163      MX17004  2010      6  d17  28.0  17.5
# 176      MX17004  2010      6  d29  30.1  18.0
# 191      MX17004  2010      7  d14  29.9  16.5
# 208      MX17004  2010      7   d3  28.6  17.5
# 221      MX17004  2010      8  d13  29.8  16.5
# 232      MX17004  2010      8  d23  26.4  15.0
# 234      MX17004  2010      8  d25  29.7  15.6
# 238      MX17004  2010      8  d29  28.0  15.3
# 241      MX17004  2010      8  d31  25.4  15.4
# ...

# %% [markdown]
# ### *Normalization*

# %%
billboard_songs = billboard_long[['year','artist','track','time']]
billboard_songs.head()
# Out:
#    year        artist                    track  time
# 0  2000       2Ge+her  The Hardest Part Of ...  3:15
# 1  2000         2 Pac           Baby Don't Cry  4:22
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35

# %%
billboard_songs.shape
# Out:
# (24092, 4)

# %%
billboard_songs = billboard_songs.drop_duplicates()
billboard_songs.head()
# Out:
#    year        artist                    track  time
# 0  2000       2Ge+her  The Hardest Part Of ...  3:15
# 1  2000         2 Pac           Baby Don't Cry  4:22
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35

# %%
billboard_songs.shape
# Out:
# (317, 4)

# %%
billboard_songs['id'] = range(len(billboard_songs))
billboard_songs.head()
# Out:
#    year        artist                    track  time  id
# 0  2000       2Ge+her  The Hardest Part Of ...  3:15   0
# 1  2000         2 Pac           Baby Don't Cry  4:22   1
# 2  2000  3 Doors Down               Kryptonite  3:53   2
# 3  2000  3 Doors Down                    Loser  4:24   3
# 4  2000      504 Boyz            Wobble Wobble  3:35   4

# %%
billboard_ratings = billboard_long.merge(billboard_songs, on=['year','artist','track','time'])
billboard_ratings.head()
# Out:
#    year   artist                    track  time date.entered week  rating  id
# 0  2000  2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1    91.0   0
# 1  2000  2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk2    87.0   0
# 2  2000  2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk3    92.0   0
# 3  2000  2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk4     NaN   0
# 4  2000  2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk5     NaN   0

# %%
billboard_ratings = billboard_ratings[['id','date.entered','week','rating']]
billboard_ratings.head()
# Out:
#    id date.entered week  rating
# 0   0   2000-09-02  wk1    91.0
# 1   0   2000-09-02  wk2    87.0
# 2   0   2000-09-02  wk3    92.0
# 3   0   2000-09-02  wk4     NaN
# 4   0   2000-09-02  wk5     NaN

# %%
import glob

# %%
concat_files = glob.glob('../data/concat*')

# %%
list_concat_df = [ pd.read_csv(csv_filename) for csv_filename  in concat_files]

# %%
concat_loop = pd.concat(list_concat_df)
concat_loop
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
