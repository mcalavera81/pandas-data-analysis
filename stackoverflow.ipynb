# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option("display.max_columns",1000)
pd.set_option("display.max_rows",500)

# %%
schema  = pd.read_csv('./survey_results_schema.csv')
df = pd.read_csv('./survey_results_public.csv')

# %%
schema
# Out:
#                                Column  \
# 0    Respondent
# 1    Professional
# 2    ProgramHobby
# 3    Country
# 4    University
# 5    EmploymentStatus
# 6    FormalEducation
# 7    MajorUndergrad
# 8    HomeRemote
# 9    CompanySize
# 10   CompanyType
# 11   YearsProgram
# 12   YearsCodedJob
# 13   YearsCodedJobPast
# 14   DeveloperType
# 15   WebDeveloperType
# 16   MobileDeveloperType
# 17   NonDeveloperType
# 18   CareerSatisfaction
# 19   JobSatisfaction
# 20   ExCoderReturn
# 21   ExCoderNotForMe
# 22   ExCoderBalance
# 23   ExCoder10Years
# 24   ExCoderBelonged
# 25   ExCoderSkills
# 26   ExCoderWillNotCode
# 27   ExCoderActive
# 28   PronounceGIF
# 29   ProblemSolving
# 30   BuildingThings
# 31   LearningNewTech
# 32   BoringDetails
# 33   JobSecurity
# 34   DiversityImportant
# 35   AnnoyingUI
# 36   FriendsDevelopers
# 37   RightWrongWay
# 38   UnderstandComputers
# 39   SeriousWork
# 40   InvestTimeTools
# 41   WorkPayCare
# 42   KinshipDevelopers
# ...

# %%
pd.get_option("display.max_columns")
# Out:
# 1000

# %%
df.head()
# Out:
#    Respondent                                          Professional               ProgramHobby         Country      University                        EmploymentStatus                                                    FormalEducation                                 MajorUndergrad                                               HomeRemote               CompanySize                                                            CompanyType      YearsProgram     YearsCodedJob YearsCodedJobPast                                                           DeveloperType WebDeveloperType MobileDeveloperType NonDeveloperType  CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills ExCoderWillNotCode ExCoderActive                  PronounceGIF  ProblemSolving  BuildingThings LearningNewTech   BoringDetails     JobSecurity DiversityImportant AnnoyingUI FriendsDevelopers   RightWrongWay UnderstandComputers     SeriousWork  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University', 'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote', 'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race', 'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing', 'InterestedAnswers', 'Salary', 'ExpectedSalary'], dtype='object', length=154)

# %%
df.YearsCodedJob.value_counts()
# Out:
# 1 to 2 years        5289
# 2 to 3 years        4767
# 3 to 4 years        4003
# 4 to 5 years        3405
# 20 or more years    3067
# Less than a year    3034
# 5 to 6 years        2990
# 9 to 10 years       1956
# 6 to 7 years        1912
# 10 to 11 years      1678
# 7 to 8 years        1638
# 8 to 9 years        1287
# 15 to 16 years      845
# 14 to 15 years      840
# 11 to 12 years      838
# 12 to 13 years      741
# 16 to 17 years      694
# 17 to 18 years      545
# 13 to 14 years      531
# 19 to 20 years      427
# 18 to 19 years      403
# Name: YearsCodedJob, dtype: int64

# %%
import numpy as np
df[(df.Country=='Spain') & (df.DeveloperType=='Web developer')].groupby(['YearsProgram'])['Salary'].agg(['mean','count'])
# Out:
#                           mean  count
# YearsProgram
# 1 to 2 years      33870.967742  1
# 10 to 11 years    33691.756272  6
# 11 to 12 years   NaN            0
# 12 to 13 years    36200.716846  6
# 13 to 14 years    32258.064516  2
# 14 to 15 years    24596.774194  4
# 15 to 16 years    35842.293907  6
# 16 to 17 years    33440.860215  4
# 17 to 18 years    35842.293907  3
# 18 to 19 years    41577.060932  3
# 19 to 20 years    35483.870968  1
# 2 to 3 years      20430.107527  4
# 20 or more years  37670.250896  12
# 3 to 4 years      22580.645161  2
# 4 to 5 years      35663.082437  6
# 5 to 6 years      23172.043011  8
# 6 to 7 years      28591.397849  10
# 7 to 8 years      29882.697947  11
# 8 to 9 years      34365.591398  1
# 9 to 10 years     56550.268817  4
# Less than a year  29569.892473  1

# %%
df.DeveloperType.value_counts()
# Out:
# Web developer                                                                                                                                                                                                                                                                                                                                                10683
# Web developer; Desktop applications developer                                                                                                                                                                                                                                                                                                                1849
# ...

# %%
len(df[df.Country == 'Spain'])/len(df)
# Out:
# 0.016811955168119553

# %%
len(df)
# Out:
# 51392

# %%
df.HaveWorkedLanguage
# Out:
# 0        Swift
# 1        JavaScript; Python; Ruby; SQL
# 2        Java; PHP; Python
# 3        Matlab; Python; R; SQL
# 4        NaN
# 5        JavaScript; PHP; Rust
# 6        Matlab; Python
# 7        CoffeeScript; Clojure; Elixir; Erlang; Haskell; JavaScript; Python; Ruby
# 8        C#; JavaScript
# 9        Objective-C; Swift
# 10       R; SQL
# 11       NaN
# 12       C; C++; Java
# 13       Java; JavaScript; Ruby; SQL
# 14       Assembly; C; C++
# 15       JavaScript; VB.NET
# 16       JavaScript
# 17       C; Clojure; JavaScript; Matlab; Rust; SQL; Swift
# 18       NaN
# 19       Perl; Python
# 20       NaN
# 21       C#; JavaScript; SQL
# 22       Java
# 23       PHP; SQL
# 24       NaN
# 25       Java; Scala
# 26       Java; JavaScript; Objective-C; Python; Swift
# 27       NaN
# 28       JavaScript; Python
# 29       NaN
# 30       NaN
# 31       NaN
# 32       C#; Java
# 33       JavaScript
# 34       Assembly; C
# 35       C#; JavaScript; Matlab; Python; R
# ...

# %%
print(df.iloc[:,154:].columns.tolist())
# Out:
# []

# %%
df.HaveWorkedLanguage = df.HaveWorkedLanguage.astype(str)
for idx, row in df.iterrows():
    print(row.HaveWorkedLanguage)
    for hobby in row.HaveWorkedLanguage.split(";"):
        hobby = hobby.strip().lower()
        df.loc[idx, hobby] = True

df.fillna(False, inplace=True)
# Out:
# Swift
# JavaScript; Python; Ruby; SQL
# Java; PHP; Python
# Matlab; Python; R; SQL
# nan
# JavaScript; PHP; Rust
# Matlab; Python
# CoffeeScript; Clojure; Elixir; Erlang; Haskell; JavaScript; Python; Ruby
# C#; JavaScript
# Objective-C; Swift
# R; SQL
# nan
# C; C++; Java
# Java; JavaScript; Ruby; SQL
# Assembly; C; C++
# JavaScript; VB.NET
# JavaScript
# C; Clojure; JavaScript; Matlab; Rust; SQL; Swift
# nan
# Perl; Python
# nan
# C#; JavaScript; SQL
# Java
# PHP; SQL
# nan
# Java; Scala
# Java; JavaScript; Objective-C; Python; Swift
# nan
# JavaScript; Python
# nan
# nan
# nan
# C#; Java
# JavaScript
# Assembly; C
# C#; JavaScript; Matlab; Python; R
# C#; F#; JavaScript; SQL
# C#; Java; JavaScript
# C#; JavaScript; SQL; TypeScript
# nan
# C; C++; JavaScript; Lua; Python
# nan
# Java; JavaScript; SQL
# nan
# Java; JavaScript; SQL; VBA
# C; C++; Groovy; Java; Python
# nan
# C++; C#; Java; JavaScript; Lua; SQL
# JavaScript; Ruby
# C#; Java; SQL
# JavaScript
# ...

# %%
df.iloc[:5,154:]
# Out:
#    swift  javascript  python   ruby    sql   java    php  matlab      r    nan   rust  coffeescript  clojure  elixir  erlang  haskell     c#  objective-c      c    c++  assembly  vb.net   perl  scala     f#  typescript    lua    vba  groovy     go  smalltalk  visual basic 6  common lisp   dart  julia   hack
# 0  True   False       False   False  False  False  False  False   False  False  False  False         False    False   False   False    False  False        False  False  False     False   False  False  False  False       False  False  False   False  False      False           False        False  False  False
# 1  False  True        True    True   True   False  False  False   False  False  False  False         False    False   False   False    False  False        False  False  False     False   False  False  False  False       False  False  False   False  False      False           False        False  False  False
# ...

# %%
df.iloc[:5,154:].join(df['Country'])
# Out:
#    swift  javascript  python   ruby    sql   java    php  matlab      r    nan   rust  coffeescript  clojure  elixir  erlang  haskell     c#  objective-c      c    c++  assembly  vb.net   perl  scala     f#  typescript    lua    vba  groovy     go  smalltalk  visual basic 6  common lisp   dart  julia   hack         Country
# 0  True   False       False   False  False  False  False  False   False  False  False  False         False    False   False   False    False  False        False  False  False     False   False  False  False  False       False  False  False   False  False      False           False        False  False  False  United States
# 1  False  True        True    True   True   False  False  False   False  False  False  False         False    False   False   False    False  False        False  False  False     False   False  False  False  False       False  False  False   False  False      False           False        False  False  False  United Kingdom
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))

df[df.Country=='Spain'].iloc[:,154:].sum().sort_values(ascending=True).plot(kind ='barh', rot=0)

# %%
df.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University', 'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote', 'CompanySize',
#        ...
#        'lua', 'vba', 'groovy', 'go', 'smalltalk', 'visual basic 6', 'common lisp', 'dart', 'julia', 'hack'], dtype='object', length=190)

# %%
df.HaveWorkedFramework = df.HaveWorkedFramework.astype(str)
for idx, row in df.iterrows():
    for hobby in row.HaveWorkedFramework.split(";"):
        hobby = hobby.strip().lower()
        df.loc[idx, hobby] = True

df.fillna(False, inplace=True)

# %% [markdown]
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.figure(figsize=(20,20))
#
# df[df.Country=='Spain'].iloc[:,191:].sum().sort_values(ascending=True).plot(kind ='barh', rot=0)

# %%
df[df.Country=='Spain'].HaveWorkedFramework.value_counts()
# Out:
# False                                                      548
# AngularJS                                                  44
# Node.js                                                    37
# .NET Core                                                  34
# AngularJS; Node.js                                         26
# AngularJS; Node.js; Cordova                                16
# Node.js; React                                             9
# AngularJS; Cordova                                         9
# AngularJS; Node.js; React                                  9
# Firebase                                                   9
# Xamarin; .NET Core                                         8
# Hadoop; Spark                                              8
# React                                                      8
# AngularJS; Node.js; Cordova; Firebase                      6
# AngularJS; Node.js; React; Cordova                         6
# ...
